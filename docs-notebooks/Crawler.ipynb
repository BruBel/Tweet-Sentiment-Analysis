# %%
import tweepy
import csv
import pandas as pd
from pprint import pprint

####input your credentials here
consumer_key = 'SM7Sd6W9s6FBUr3V4yONxuAYe'
consumer_secret = 'X8zde1H80NjMOSO1WtPQ8gKeq7UPLyNGJR2ymrAWGsoLpBtPTs'
access_token = '1233009049341452288-2bLG9EDiQWsCGYlP6rtXh77U2v30Nj'
access_token_secret = 'vHWXXONFQGIMJVbGHtwi1NMvuLfZN0KJ0ztSlGSOOqHLu'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
#####United Airlines
# Open/Create a file to append data

# %%
df = pd.DataFrame()

dates = []
tweets = []
actual_date = 0
count_tweets = 0
limit_date = '1/3/2020'
for tweet in tweepy.Cursor(api.search,q='#palmeiras',
                       lang="pt",
                       tweet_mode="extended").items():
    
    pprint(tweet._json)

    ts = tweet.created_at

    date = str(ts.day)+"/"+str(ts.month)+"/"+str(ts.year)

    if actual_date == 0:

        actual_date = date

    if date != actual_date:
        print(date)
        print('New Date')
        actual_date = date

    
    if date == limit_date:
        break

    dates.append(date)
    tweets.append(tweet._json["full_text"])

df['date'] = dates
df['tweet'] = tweets
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Mar 19 12:08:57 +0000 2020',
#  'display_text_range': [0, 82],
#  'entities': {'hashtags': [{'indices': [45, 59], 'text': 'JogandoEmCasa'},
#                            {'indices': [60, 70], 'text': 'Palmeiras'},
#                            {'indices': [71, 82], 'text': 'Fluminense'}],
#               'media': [{'display_url': 'pic.twitter.com/JLJUIrdl6F',
#                          'expanded_url': 'https://twitter.com/thescoborges/status/1240611214369136641/photo/1',
#                          'id': 1240611204869095424,
#                          'id_str': '1240611204869095424',
#                          'indices': [83, 106],
#                          'media_url': 'http://pbs.twimg.com/media/ETeJUVqXgAACdF1.jpg',
#                          'media_url_https': 'https://pbs.twimg.com/media/ETeJUVqXgAACdF1.jpg',
#                          'sizes': {'large': {'h': 1621,
# ...

# %%
df
# Out:
#          date                                              tweet
# 0    4/3/2020  passando rápido para lembrar que o @Palmeiras ...
# 1    4/3/2020  Hoje tem #Palmeiras hoje tem  #Libertadores  A...
# 2    4/3/2020       Hoje teeem Palmeiras!! 💚\n#BomDia #Palmeiras
# 3    4/3/2020  Manto novo para escrevermos juntos uma nova hi...
# 4    4/3/2020  Agora sim ! vinicius10_mc7 lolacolella palmeir...
# ..        ...                                                ...
# 455  2/3/2020  RT @csepitapolis: Confira todos os jogos do @P...
# 456  2/3/2020  Março tem três jogos da Libertadores e um clás...
# 457  2/3/2020  Cruzeiro negocia com o Palmeiras a chegada do ...
# 458  2/3/2020  RT @Ademir_daGuia: Há 46 anos, o Hexa vinha! O...
# 459  2/3/2020  PAL | Segue forte. Difícil, mas só uma sequênc...
#
# [460 rows x 2 columns]

# %%
count = df['date'].value_counts()

# %%
count.index
# Out:
# Index(['3/3/2020', '2/3/2020', '4/3/2020'], dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.lineplot(count.index, count.values)

# %% [markdown]
# # Mongo DB

# %%
import pymongo

# %%
client = pymongo.MongoClient('mongodb+srv://brunobelluzzo:bruno0911@twitteranalysis-zrfix.mongodb.net/test?retryWrites=true&w=majority')

# %%
db = client.Twitter

# %%
db.tweets.insert_one({'a': 'b'})
