# %%
import tweepy
import csv
import pandas as pd

####input your credentials here
consumer_key = 'SM7Sd6W9s6FBUr3V4yONxuAYe'
consumer_secret = 'X8zde1H80NjMOSO1WtPQ8gKeq7UPLyNGJR2ymrAWGsoLpBtPTs'
access_token = '1233009049341452288-2bLG9EDiQWsCGYlP6rtXh77U2v30Nj'
access_token_secret = 'vHWXXONFQGIMJVbGHtwi1NMvuLfZN0KJ0ztSlGSOOqHLu'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
#####United Airlines
# Open/Create a file to append data

# %%
df = pd.DataFrame()

dates = []
tweets = []
actual_date = 0
count_tweets = 0
limit_date = '2/3/2020'
for tweet in tweepy.Cursor(api.search,q='#palmeiras',
                       lang="pt",
                       tweet_mode="extended").items():

    ts = tweet.created_at

    date = str(ts.day)+"/"+str(ts.month)+"/"+str(ts.year)

    if actual_date == 0:

        actual_date = date

    if date != actual_date:
        print(date)
        print('New Date')
        actual_date = date

    
    if date == limit_date:
        break

    dates.append(date)
    tweets.append(tweet._json["full_text"])

df['date'] = dates
df['tweet'] = tweets
# Out:
# 2/3/2020
# New Date

# %%
df
# Out:
#          date                                              tweet
# 0    3/3/2020  #Libertadores - O #Grêmio entra em campo hoje ...
# 1    3/3/2020  IMPERDÍVEL! #Flamengo, #Santos, #SãoPaulo, #Gr...
# 2    3/3/2020  RT @dimensao_esp: Nossos colunistas palpitaram...
# 3    3/3/2020  Nossos colunistas palpitaram quem vai vencer o...
# 4    3/3/2020  RT @alterosaesp: NA ÁREA: volante Jean, do @Pa...
# ..        ...                                                ...
# 139  3/3/2020  RT @RivotrilN: O cara só perguntou se o #Palme...
# 140  3/3/2020  RT @PortalDaBase: CBF detalha tabela da primei...
# 141  3/3/2020  CBF detalha tabela da primeira fase da Copa do...
# 142  3/3/2020  SEGUE O LÍDER GAMBÁ!\n😂🐖🤘🐽🤙🐷😁🐽\n#BiEliminado \...
# 143  3/3/2020  SEGUE O LÍDER GAMBÁ!\n😂🐖🤘🐽🤙🐷😁🐽\n#BiEliminado \...
#
# [144 rows x 2 columns]
