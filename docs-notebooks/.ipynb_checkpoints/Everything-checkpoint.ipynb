# %%
import pandas as pd
import numpy as np
import pymongo
from collections import Counter

# %%
resp = {
    "values": [
        {
            "hashtag": "#dota",
            "tweets": [
                {
                    "date": "17/3/2020",
                    "tweet_text": "Pra quem tem o desejo de competir está aí uma ótima oportunidade e com a chance de embolsar um ótimo prêmio!\nLiga Urso #5\n#Underlords #DotaUnderlords #Valve #Dota2 #Dota #AutoBattler https://t.co/of3AaciL71",
                    "sentiment": {
                        "sentiment": {
                            "preds": "Positivo",
                            "probabilities": 0.5666666666666667
                        }
                    }
                },
                {
                    "date": "16/3/2020",
                    "tweet_text": "Capa para #twitch e #streamer #Bizarelli (#Beatromba) \n- design @renanfest2 \n#meepo #mepo #dota #dota2 https://t.co/2dnQE7PX3N",
                    "sentiment": {
                        "sentiment": {
                            "preds": "Positivo",
                            "probabilities": 0.5666666666666667
                        }
                    }
                },
                {
                    "date": "15/3/2020",
                    "tweet_text": "RT @MARCAOMAXIMUS: Bora bora\n#facebookgaming \n#games #jogos #freefire #CoDWarzone #CallofDuty #lol #LeagueOfLegends #lolzinho #dota2 #dota",
                    "sentiment": {
                        "sentiment": {
                            "preds": "Positivo",
                            "probabilities": 0.5666666666666667
                        }
                    }
                },
                {
                    "date": "15/3/2020",
                    "tweet_text": "Bora bora\n#facebookgaming \n#games #jogos #freefire #CoDWarzone #CallofDuty #lol #LeagueOfLegends #lolzinho #dota2 #dota",
                    "sentiment": {
                        "sentiment": {
                            "preds": "Positivo",
                            "probabilities": 0.5666666666666667
                        }
                    }
                },
                {
                    "date": "14/3/2020",
                    "tweet_text": "E vamos de Dota #dota2 #dota",
                    "sentiment": {
                        "sentiment": {
                            "preds": "Positivo",
                            "probabilities": 0.5666666666666667
                        }
                    }
                },
                {
                    "date": "10/3/2020",
                    "tweet_text": "RT @AlemDoCume: Semana mal começou e a gente já tá de olho é na 👻 SEXTA-FEIRA 13 👻 tem muito #DOTA pro lado dos temidos.\n\nAMANHÃ TRANSMISSÃ…",
                    "sentiment": {
                        "sentiment": {
                            "preds": "Positivo",
                            "probabilities": 0.5666666666666667
                        }
                    }
                }
            ]
        }
    ]
}

# %%
dates = [date['date'] for date in resp['values'][0]['tweets']]

# %%
Counter(dates)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-363fbce15e1a> in <module>
# ----> 1 Counter(dates)
#
# NameError: name 'Counter' is not defined
